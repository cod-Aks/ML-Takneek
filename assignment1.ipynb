# %% [markdown]
# ## <center>  <b> NLP Navigator - Assignment 1 </b>  </center>

# %% [markdown]
# This is the first assignment of the project and will test your basic python skills and what you have learnt so far about the libraries like numpy and matplotlib. The problem statement and your tasks are described below. You have to rename the notebook as `{Your Name}_Assignment1.ipynb` and write all the code and then generate outputs in it. Submission will be on github and more guidelines will be given soon. The deadline to submit the assignment is `10th June 5:00 PM`

# %% [markdown]
# Given a set of $ n $ points in $ d $ dimensional Euclidean Space, we will find all pairs of points whose Euclidean distance is less than $ r $.
#
# Let  $ \overrightarrow{P_1} = (P_{11},P_{12}, \ldots, P_{1d}) $ and $ \overrightarrow{P_2} = (P_{21},P_{22}, \ldots, P_{2d}) $ be two points. Then the Euclidean distance between them is equal to the norm $ \left|\left| \overrightarrow{P_1} - \overrightarrow{P_2} \right|\right| $.
#
# We have to find the set $ A = \left\{(i, j): \left|\left| \overrightarrow{P_1} - \overrightarrow{P_2} \right|\right| \leq r \right\} $ where $ i,j \in \{1,2,3,...,n\} $.
#
#
# Obviously we can find it by using 2 nested loops and searching over all pairs, but we will do the task in an optimised way. Let us make a grid where each cell is of dimension $ r \times r $. Then, (say d = 2)
#
# ![graph1](https://drive.google.com/uc?export=view&id=1qIcPgkv9Q3fI-eV5AaAobjFIYy_2siZN)
#
# Divide the points into the cells based on their coordinates. For example, say $ 4 $ points $ \left( \frac{1}{2}, \frac{2}{3} \right), \left( \frac{2}{3}, \frac{3}{2} \right), \left( 1, 1 \right), \left( \frac{3}{2}, \frac{5}{2} \right) $ and $ r = 1 $. So the division should be like -
#
# ![graph2](https://drive.google.com/uc?export=view&id=1-u-mT1PTxOkow_uz0T8ZBjU35u63uU7F)
#
# Now comes the observation: For any point, the points which are within distance $ d $ from it must lie in 8 adjacent cells and no where else. So, for every point, just search the points present in 8 adjacent cells, and add the valid pairs to the answer set $ A $. Please note that for corner cells, the number of adjacent cells will not be equal to 8. So, write your code including those cases also.
# ##### Some points for higher dimension cases:
# 1. Think whether the number of adjacent cells for higher dimensions will be 8 or more (or less).
# 2. Observe that the dimension of each cell will not be $r*r$ for each case.
# ##### <u>Note</u>: Assume the pair $ (i,j) $ and $ (j,i) $ to be same. So write your code accordingly. For example, in 2-D space, we will count $ ((1,2), (4,5)) $ and $ ((4,5), (1,2)) $ only once.

# %% [markdown]
# ## Tasks TO DO:
#
# 1. Generate a set of $ 1000 $ random points in $ 2 $ dimensional space with coordinates ranging between 0 and 100.
# 2. For $ r = \{ 1, 2, \ldots, 10 \} $, divide the points into grid as shown.
#    - Show using matplotlib the various points using different colours.
#    - Find pairs and store them in a list/set $ A $
# 3. Do task 1 and 2 for $ d = 3, 4, 10, 50, 100 $ (except plotting) and store the results.
# (You can also plot for $ d = 3 $ but it is optional)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.widgets import RectangleSelector
from sklearn.neighbors import KDTree
import random
import array
import math

# %%
coordinates = np.random.randint(0,100, size = (1000, 2))
coordinates
x=[]
y=[] 
for i in range(1000):
 x.append( coordinates[i][0])
 y.append(coordinates[i][1])
print(x)
print(y)

coordinates
# Out:
# [98, 64, 70, 98, 23, 18, 31, 22, 47, 44, 71, 61, 99, 77, 4, 40, 73, 37, 68, 96, 33, 35, 26, 15, 96, 51, 97, 73, 87, 76, 57, 76, 42, 70, 75, 61, 65, 75, 51, 62, 66, 20, 9, 82, 40, 34, 34, 12, 56, 63, 80, 69, 8, 81, 67, 43, 86, 65, 50, 99, 67, 12, 3, 96, 99, 57, 0, 95, 39, 26, 74, 66, 89, 77, 86, 40, 28, 51, 52, 7, 9, 19, 86, 73, 27, 41, 88, 15, 37, 23, 73, 16, 24, 80, 90, 49, 86, 40, 63, 48, 43, 16, 98, 43, 20, 85, 10, 65, 37, 99, 49, 58, 50, 25, 49, 31, 1, 93, 58, 83, 46, 36, 63, 0, 1, 28, 11, 41, 25, 68, 83, 70, 71, 25, 72, 96, 70, 52, 79, 60, 75, 50, 39, 81, 65, 51, 95, 19, 44, 34, 60, 57, 97, 14, 3, 83, 77, 64, 12, 51, 97, 80, 83, 50, 54, 28, 73, 20, 78, 83, 88, 33, 78, 6, 3, 94, 86, 17, 30, 36, 8, 60, 21, 75, 67, 76, 47, 90, 64, 1, 25, 90, 77, 39, 65, 10, 73, 12, 88, 13, 88, 30, 92, 27, 92, 55, 10, 81, 9, 22, 94, 12, 84, 97, 59, 12, 45, 71, 23, 53, 44, 13, 45, 59, 21, 63, 87, 62, 65, 64, 53, 54, 68, 81, 15, 30, 73, 68, 23, 47, 57, 90, 87, 60, 60, 98, 54, 95, 69, 72, 20, 88, 4, 86, 47, 61, 11, 64, 82, 9, 60, 48, 76, 66, 57, 49, 46, 28, 64, 65, 4, 1, 18, 70, 22, 62, 38, 27, 72, 94, 93, 9, 42, 53, 94, 99, 43, 61, 93, 83, 72, 63, 7, 82, 44, 75, 40, 47, 69, 26, 37, 8, 30, 60, 62, 7, 26, 16, 67, 37, 96, 72, 5, 51, 78, 30, 36, 81, 63, 6, 68, 23, 39, 62, 53, 74, 18, 38, 5, 76, 1, 56, 74, 63, 82, 86, 6, 74, 13, 81, 65, 61, 82, 82, 96, 64, 37, 94, 1, 42, 27, 99, 94, 45, 97, 92, 4, 19, 78, 14, 1, 24, 38, 51, 12, 43, 95, 35, 26, 17, 38, 26, 42, 73, 60, 90, 32, 95, 33, 85, 85, 15, 67, 55, 18, 33, 73, 1, 17, 42, 2, 3, 98, 40, 36, 23, 26, 82, 50, 36, 67, 43, 61, 26, 23, 85, 8, 16, 32, 90, 57, 26, 49, 73, 81, 93, 96, 5, 89, 52, 48, 57, 88, 60, 69, 56, 53, 43, 59, 75, 77, 76, 50, 44, 89, 63, 66, 6, 25, 50, 17, 68, 61, 57, 23, 71, 54, 98, 68, 21, 67, 55, 85, 34, 88, 25, 47, 23, 14, 4, 35, 27, 15, 43, 94, 8, 27, 93, 8, 62, 92, 40, 81, 26, 69, 98, 11, 40, 61, 83, 19, 82, 1, 67, 49, 10, 53, 38, 23, 16, 94, 8, 86, 59, 26, 23, 84, 48, 7, 51, 54, 23, 94, 26, 68, 77, 74, 48, 97, 97, 17, 96, 72, 39, 14, 21, 56, 4, 45, 86, 48, 11, 58, 5, 66, 67, 73, 28, 92, 61, 66, 7, 60, 25, 44, 43, 24, 10, 53, 86, 31, 5, 89, 89, 11, 20, 78, 79, 45, 30, 45, 37, 29, 72, 95, 14, 5, 15, 86, 53, 37, 65, 33, 64, 36, 27, 65, 6, 6, 73, 21, 56, 67, 3, 9, 58, 86, 14, 98, 43, 70, 90, 43, 96, 19, 27, 66, 23, 48, 33, 67, 59, 13, 44, 59, 77, 85, 10, 79, 50, 17, 86, 38, 3, 18, 51, 7, 42, 97, 38, 66, 66, 78, 55, 23, 6, 40, 12, 27, 1, 45, 62, 22, 59, 41, 78, 58, 38, 35, 26, 20, 92, 22, 1, 50, 11, 93, 51, 16, 24, 64, 61, 27, 32, 22, 80, 38, 75, 95, 77, 74, 83, 78, 59, 52, 90, 0, 49, 2, 45, 11, 89, 4, 30, 83, 59, 46, 94, 9, 73, 94, 91, 53, 38, 82, 43, 38, 29, 18, 43, 88, 17, 99, 97, 1, 91, 9, 70, 13, 70, 22, 84, 79, 96, 14, 71, 97, 6, 10, 83, 42, 65, 86, 62, 94, 96, 3, 88, 26, 6, 7, 45, 57, 8, 80, 29, 54, 62, 56, 87, 19, 10, 87, 60, 20, 13, 53, 54, 60, 75, 85, 83, 69, 75, 12, 1, 94, 75, 69, 89, 47, 28, 58, 77, 62, 21, 82, 48, 0, 86, 86, 70, 42, 51, 39, 58, 93, 98, 9, 44, 56, 94, 24, 69, 67, 58, 26, 2, 75, 21, 13, 11, 33, 87, 22, 23, 28, 44, 72, 5, 59, 95, 95, 10, 83, 6, 46, 25, 88, 55, 61, 90, 70, 31, 87, 84, 90, 83, 0, 8, 12, 28, 51, 22, 95, 3, 89, 38, 23, 13, 32, 23, 34, 24, 95, 26, 77, 66, 39, 38, 96, 50, 89, 96, 87, 93, 30, 69, 16, 30, 8, 16, 52, 88, 62, 93, 4, 6, 5, 33, 73, 1, 64, 92, 54, 60, 27, 24, 66, 76, 80, 91, 97, 70, 67, 99, 89, 84, 93, 51, 37, 97, 24, 97, 42, 99, 90, 19, 34, 12, 33, 61, 77, 67, 15, 93, 71, 32, 37, 58, 67, 31, 13, 9, 78, 41, 45, 81, 79, 55, 19, 71, 79, 41, 96, 73, 21, 87, 76, 28, 96, 14, 32, 32, 49, 26, 81, 37, 11, 78, 58, 58, 78, 26, 81, 73, 7, 58, 79, 28, 97, 3, 41, 81, 15, 20, 61, 49, 29, 23, 31, 64, 93, 19, 27, 44, 94, 56, 10, 41, 35, 29, 95, 51, 1, 7, 77, 58, 44, 80, 80, 91, 5, 7, 92, 99, 81, 13, 66, 27, 25, 17, 38, 45, 57, 32, 79, 54, 98, 84, 99, 2, 43, 18, 81, 26, 37, 54, 9, 47, 36, 77, 92, 27, 72, 53, 19, 91, 35, 37, 88, 38, 1, 3, 44, 96, 98, 10, 38, 5]
# [6, 1, 97, 14, 11, 14, 52, 58, 21, 54, 25, 88, 48, 28, 84, 53, 64, 75, 84, 83, 50, 82, 60, 45, 88, 41, 91, 67, 70, 35, 74, 84, 43, 77, 1, 96, 16, 29, 28, 70, 36, 8, 0, 80, 30, 7, 41, 80, 77, 27, 47, 18, 53, 56, 9, 12, 43, 86, 5, 73, 20, 36, 45, 61, 77, 88, 43, 10, 64, 62, 42, 12, 92, 12, 51, 23, 51, 61, 31, 28, 59, 44, 35, 84, 89, 53, 93, 0, 94, 14, 51, 56, 95, 40, 80, 87, 96, 62, 47, 6, 61, 67, 24, 7, 58, 41, 72, 77, 34, 93, 36, 40, 15, 6, 87, 73, 74, 5, 23, 90, 74, 55, 95, 37, 82, 82, 31, 47, 35, 95, 41, 16, 58, 13, 96, 52, 89, 67, 19, 80, 40, 33, 38, 58, 20, 31, 6, 39, 47, 82, 95, 83, 90, 81, 60, 19, 34, 52, 24, 67, 28, 63, 59, 67, 57, 68, 14, 81, 55, 75, 80, 31, 74, 23, 51, 13, 65, 6, 95, 70, 51, 62, 64, 44, 52, 91, 99, 43, 4, 97, 37, 0, 4, 85, 23, 89, 42, 59, 66, 42, 71, 4, 18, 75, 29, 46, 69, 76, 41, 21, 59, 75, 4, 92, 33, 36, 78, 0, 32, 96, 3, 27, 58, 76, 82, 17, 99, 21, 80, 85, 42, 74, 18, 13, 46, 12, 32, 64, 75, 85, 11, 10, 30, 88, 22, 47, 9, 5, 3, 82, 34, 4, 17, 48, 25, 65, 17, 78, 64, 43, 50, 1, 18, 31, 14, 73, 70, 59, 29, 47, 77, 49, 17, 27, 40, 28, 42, 41, 69, 98, 50, 31, 45, 96, 75, 88, 18, 62, 60, 73, 52, 41, 96, 73, 68, 45, 6, 63, 57, 22, 96, 20, 59, 48, 6, 17, 22, 63, 32, 46, 98, 73, 89, 91, 34, 3, 60, 88, 58, 97, 70, 27, 92, 12, 99, 59, 71, 60, 17, 58, 13, 34, 80, 26, 10, 93, 68, 43, 87, 41, 29, 29, 77, 66, 20, 53, 27, 20, 87, 81, 24, 84, 45, 81, 79, 66, 81, 9, 74, 78, 80, 52, 37, 93, 20, 40, 8, 34, 73, 85, 88, 41, 56, 24, 71, 17, 78, 74, 90, 14, 91, 41, 4, 92, 7, 55, 65, 69, 97, 68, 71, 55, 57, 41, 65, 53, 54, 7, 71, 2, 50, 39, 30, 32, 60, 28, 10, 40, 87, 89, 79, 48, 74, 53, 16, 60, 99, 51, 65, 96, 8, 2, 35, 89, 62, 42, 35, 62, 23, 2, 14, 77, 83, 69, 40, 76, 2, 6, 11, 20, 31, 88, 24, 96, 79, 27, 22, 56, 74, 58, 94, 27, 23, 97, 37, 83, 34, 79, 50, 85, 88, 55, 43, 82, 35, 9, 58, 36, 11, 91, 89, 55, 16, 98, 95, 51, 45, 53, 2, 78, 83, 82, 25, 23, 34, 48, 20, 43, 62, 87, 41, 82, 29, 81, 86, 81, 28, 67, 78, 57, 45, 72, 8, 48, 85, 43, 2, 62, 4, 64, 86, 52, 44, 2, 73, 43, 73, 49, 50, 57, 59, 77, 36, 20, 35, 59, 98, 77, 30, 46, 85, 62, 85, 36, 99, 73, 91, 10, 50, 40, 42, 58, 16, 98, 40, 42, 42, 0, 3, 85, 35, 49, 60, 41, 66, 9, 76, 67, 18, 68, 20, 48, 19, 83, 2, 58, 46, 39, 85, 85, 27, 18, 66, 78, 20, 92, 42, 27, 34, 57, 65, 43, 92, 11, 23, 78, 74, 93, 82, 39, 59, 17, 18, 98, 36, 58, 68, 1, 21, 12, 41, 62, 48, 60, 41, 46, 16, 39, 95, 0, 36, 16, 22, 7, 24, 57, 49, 5, 25, 39, 68, 80, 48, 49, 19, 65, 54, 80, 79, 91, 17, 73, 74, 43, 78, 89, 87, 50, 84, 18, 51, 92, 60, 49, 4, 48, 77, 20, 19, 39, 38, 59, 66, 86, 62, 19, 66, 22, 7, 79, 48, 17, 21, 29, 78, 77, 6, 48, 28, 63, 48, 94, 21, 64, 57, 88, 14, 24, 34, 76, 22, 16, 90, 68, 4, 43, 76, 79, 3, 81, 16, 69, 43, 76, 34, 4, 17, 69, 81, 23, 83, 16, 91, 70, 42, 1, 0, 40, 94, 18, 84, 90, 87, 48, 62, 77, 57, 7, 34, 81, 6, 8, 15, 88, 42, 25, 90, 5, 53, 62, 14, 94, 92, 30, 20, 67, 96, 96, 56, 31, 34, 57, 31, 82, 16, 72, 33, 96, 75, 99, 71, 90, 37, 0, 95, 62, 80, 5, 64, 44, 64, 11, 63, 63, 66, 24, 54, 69, 11, 37, 25, 55, 82, 62, 19, 69, 12, 43, 53, 58, 40, 49, 84, 6, 54, 20, 94, 70, 57, 18, 22, 24, 15, 78, 94, 5, 90, 82, 76, 31, 32, 3, 24, 56, 51, 95, 0, 50, 69, 61, 92, 3, 34, 27, 95, 73, 74, 95, 33, 27, 49, 7, 36, 71, 49, 99, 66, 8, 28, 38, 71, 63, 3, 93, 88, 24, 37, 54, 3, 48, 67, 41, 65, 86, 94, 15, 74, 51, 11, 11, 1, 65, 92, 1, 59, 5, 35, 11, 54, 65, 9, 14, 92, 43, 75, 73, 95, 92, 81, 83, 96, 33, 45, 92, 25, 83, 6, 32, 97, 66, 67, 85, 30, 77, 14, 9, 22, 99, 98, 13, 37, 58, 87, 90, 15, 69, 44, 12, 20, 4, 11, 44, 9, 93, 87, 13, 42, 93, 26, 37, 21, 59, 16, 65, 15, 45, 73, 73, 73, 53, 20, 0, 17, 64, 75, 80, 26, 29, 83, 74, 18, 23, 47, 92, 36, 72, 57, 28, 57, 85, 19, 23, 44, 53, 82, 8, 10, 80, 74, 45, 61, 72, 25, 98, 62, 98, 9, 50, 53, 81, 41, 62, 70, 2, 14, 91, 35, 47, 90, 46, 9, 8, 70, 23, 39, 88, 56, 22, 10, 50, 57, 69, 58, 96, 10, 60, 15, 18, 74, 33, 84, 73, 9, 21, 40, 40, 94, 19, 65, 71]
# array([[98,  6],
#        [64,  1],
#        [70, 97],
#        ...,
#        [10, 19],
#        [38, 65],
#        [ 5, 71]])

# %%
color_arr = np.random.rand(1000)
fig,ax = plt.subplots()
plt.scatter(x,y, c =color_arr, s= 1)
plt.xticks(range(0,100,5))
plt.yticks(range(0,100,5))
plt.grid()
plt.grid(True,axis='x')

# %%
print(f'points can be {coordinates[0]} and {coordinates[5]} and {r} and distance between them {math.sqrt(((coordinates[0][0]-coordinates[5][0])**2) + ((coordinates[0][1]-coordinates[5][1])**2))}')
# Out:
# points can be [89 25] and [92 53] and 5 and distance between them 28.160255680657446

# %%
r = int(input('Enter the grid between u want the points'))
a = []
for i in range(1000):
    for j in range(1000):
        if x[i] ==x[j] and y[i] == y[j]:
          continue
        if x[i] == 100:
          if x[i]-r <= x[j] and y[i]- r <= y[j] <= y[i]+ r and dist(x[i],x[j],y[i],y[j]) <=r:
           a.append(( (x[i],y[i]),(x[j], y[j])))
        elif x[i] == 0 :
         if x[i]+r >= x[j] and  y[i]- r <= y[j] <= y[i]+ r and dist(x[i],x[j],y[i],y[j]) <=r:
           a.append(((x[i],y[i]),(x[j],y[j])))
        elif y[i] == 0:
         if  y[i]+r >= y[j] and  x[i]- r <= x[j] <= x[i]+ r and dist(x[i],x[j],y[i],y[j]) <=r:
           a.append(((x[i],y[i]),(x[j],y[j])))
        elif y[i] ==100:
          if y[i]-r <= y[j] and  x[i]- r <= x[j] <= x[i]+ r and dist(x[i],x[j],y[i],y[j]) <=r:
            a.append((x[i],y[i]),(x[j],y[j]))
        elif  x[i]-r <=x[j] <= x[i]+r and y[i]-r <=y[j] <= y[i] and dist(x[i],x[j],y[i],y[j]) <=r :
            a.append(((x[i],y[i]),(x[j], y[j])))
           
        else:
          pass
a
len(a)
for i in range(len(a)):
 plt.scatter(a[i][0],a[i][1],s=1)
 plt.xticks(range(0,100,r))
 plt.yticks(range(0,100,r))
 plt.grid()
